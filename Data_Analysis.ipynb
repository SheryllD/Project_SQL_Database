# %% [markdown]
# # Data Analysis:{here name of the project}
# - here information about the overview -
#
# ## Dataset
# - here explanation about the dataset -

# %% [markdown]
# ## Libraries

# %%
#test 2

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import display
from datetime import datetime
warnings.filterwarnings('ignore')

# %%
file_path = ("Datasets_files/Data_files_Fitbit/cleaned_fitbit_data.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#            id   sleep_day  total_sleep_records  total_minutes_asleep  \
# 0  1503960366  2016-04-12                    1                   327
# 1  1503960366  2016-04-12                    1                   327
# 2  1503960366  2016-04-12                    1                   327
# 3  1503960366  2016-04-12                    1                   327
# 4  1503960366  2016-04-12                    1                   327
#
#    total_time_in_bed activity_date  total_steps  total_distance  \
# 0                346    2016-05-07        11992            7.71
# 1                346    2016-05-06        12159            8.03
# 2                346    2016-05-01        10602            6.81
# 3                346    2016-04-30        14673            9.25
# 4                346    2016-04-12        13162            8.50
#
#    tracker_distance  logged_activities_distance  ...  fairly_active_minutes  \
# 0              7.71                         0.0  ...                     46
# 1              8.03                         0.0  ...                      6
# 2              6.81                         0.0  ...                     35
# 3              9.25                         0.0  ...                     34
# 4              8.50                         0.0  ...                     13
#
#    lightly_active_minutes  sedentary_minutes  calories  day_of_the_week  \
# 0                     175                833      1821         Saturday
# 1                     289                754      1896           Friday
# 2                     246                730      1820           Sunday
# 3                     217                712      1947         Saturday
# 4                     328                728      1985          Tuesday
#
#    total_hours_asleep  total_hours_in_bed  total_exercise_minutes  \
# 0                 5.0                 6.0                    1091
# 1                 5.0                 6.0                    1073
# 2                 5.0                 6.0                    1044
# 3                 5.0                 6.0                    1015
# 4                 5.0                 6.0                    1094
#
#    total_exercise_hours Performance
# 0                  18.0         4.6
# 1                  18.0         2.2
# 2                  17.0         3.9
# 3                  17.0         5.0
# 4                  18.0         2.4
#
# [5 rows x 25 columns]
